# %%
import json
import requests
import base64

# %%
api_url = "http://localhost:8080"
users = [
    {
        "username": "user123",
        "email": "user123@example.com",
        "password": "password123"
    },
    {
        "username": "coolguy456",
        "email": "coolguy456@example.com",
        "password": "coolPass456"
    },
    {
        "username": "janeDoe789",
        "email": "janeDoe789@example.com",
        "password": "janeDoe789"
    },
    {
        "username": "alphaWolf12",
        "email": "alphaWolf12@example.com",
        "password": "alphaWolf12"
    },
    {
        "username": "betaFish34",
        "email": "betaFish34@example.com",
        "password": "betaFish34"
    },
    {
        "username": "gammaRay56",
        "email": "gammaRay56@example.com",
        "password": "gammaRay56"
    },
    {
        "username": "deltaForce78",
        "email": "deltaForce78@example.com",
        "password": "deltaForce78"
    },
    {
        "username": "epsilonWave90",
        "email": "epsilonWave90@example.com",
        "password": "epsilonWave90"
    },
    {
        "username": "zetaZone11",
        "email": "zetaZone11@example.com",
        "password": "zetaZone11"
    },
    {
        "username": "etaEnergy22",
        "email": "etaEnergy22@example.com",
        "password": "etaEnergy22"
    },
    {
        "username": "thetaTime33",
        "email": "thetaTime33@example.com",
        "password": "thetaTime33"
    },
    {
        "username": "iotaIdea44",
        "email": "iotaIdea44@example.com",
        "password": "iotaIdea44"
    },
    {
        "username": "kappaKing55",
        "email": "kappaKing55@example.com",
        "password": "kappaKing55"
    },
    {
        "username": "lambdaLion66",
        "email": "lambdaLion66@example.com",
        "password": "lambdaLion66"
    },
    {
        "username": "muMoon77",
        "email": "muMoon77@example.com",
        "password": "muMoon77"
    },
    {
        "username": "nuNight88",
        "email": "nuNight88@example.com",
        "password": "nuNight88"
    },
    {
        "username": "xiXenon99",
        "email": "xiXenon99@example.com",
        "password": "xiXenon99"
    },
    {
        "username": "omicronOrbit10",
        "email": "omicronOrbit10@example.com",
        "password": "omicronOrbit10"
    },
    {
        "username": "piPilot21",
        "email": "piPilot21@example.com",
        "password": "piPilot21"
    },
    {
        "username": "rhoRocket32",
        "email": "rhoRocket32@example.com",
        "password": "rhoRocket32"
    }
]

# %%
for user in users:
    response = requests.post(f"{api_url}/api/register",json=user)
    print(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
auth = {
        "email": "rhoRocket32@example.com",
        "password": "rhoRocket32",
    }

authReq = requests.post(
    f"{api_url}/authenticate",
    json=auth,
)


print(authReq.json())
# Out:
# {'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NjdhN2FmNTg3NTVjZjE3OGM0YTgyMTAifQ.2sMySZO2HG1Ta1ulI8oXgxcaqEBtPsdpt7AOfH4-H-g'}

# %%
with open("ma.jpeg", "rb") as img:
    imgData = img.read()
file = {"image": imgData}

# %%
file
# Out:
# {'image': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00\xbcExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x05\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00J\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00R\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00Z\x00\x00\x00\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01\x00\x07\x90\x00\x00\x07\x00\x00\x00\x040221\x91\x01\x00\x07\x00\x00\x00\x04\x01\x02\x03\x00\xa0\x00\x00\x07\x00\x00\x00\x040100\xa0\x01\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x03\x80\xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x03j\xa4\x06\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\xff\xe1\t!http://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?> <x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="XMP Core 6.0.0"> <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <rdf:Description rdf:about=""/> </rdf:RDF> </x:xmpmeta>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <?xpacket end="w"?>\x00\xff\xc0\x00\x11\x08\x03j\x03\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\x ...

# %%
post = {
    "description": "OwO",
}
authTok = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI2NjdhN2FmNTg3NTVjZjE3OGM0YTgyMTAifQ.2sMySZO2HG1Ta1ulI8oXgxcaqEBtPsdpt7AOfH4-H-g"
header = {"authorization": f"token: {authTok}"}

postReq = requests.post(
    f"{api_url}/api/posts",
    data={'json':json.dumps(post)},
    files=file,
    headers={ "authorization": f"token: {authTok}"},
)

print(postReq.json())
# Out:
# {'message': 'Invalid inputs'}
